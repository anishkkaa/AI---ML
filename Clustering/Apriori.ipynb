# %%
# Install missing package in this Jupyter environment
# Use %pip to ensure installation into the active Jupyter kernel
# %pip install mlxtend

import pandas as pd

# mlxtend imports (add type ignore to silence editor/linter "could not be resolved" warnings)
from mlxtend.preprocessing import TransactionEncoder  # type: ignore
from mlxtend.frequent_patterns import apriori, association_rules  # type: ignore
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("Groceries_dataset.csv")
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df_grouped = df.groupby(['Member_number', 'Date'])['itemDescription'].apply(list).reset_index()
df_grouped
# Out:
#        Member_number        Date  \
# 0               1000  15-03-2015
# 1               1000  24-06-2014
# 2               1000  24-07-2015
# 3               1000  25-11-2015
# 4               1000  27-05-2015
# ...              ...         ...
# 14958           4999  24-01-2015
# 14959           4999  26-12-2015
# 14960           5000  09-03-2014
# 14961           5000  10-02-2015
# 14962           5000  16-11-2014
#
#                                          itemDescription
# 0      [sausage, whole milk, semi-finished bread, yog...
# 1                      [whole milk, pastry, salty snack]
# 2                         [canned beer, misc. beverages]
# 3                            [sausage, hygiene articles]
# 4                             [soda, pickled vegetables]
# ...                                                  ...
# 14958  [tropical fruit, berries, other vegetables, yo...
# 14959                             [bottled water, herbs]
# ...

# %% [markdown]
# transactions =
# df_grouped['itemDescription'].tolist()
#     1. Libraries like mlxtend or any association rule miner typically require the input in the format.
#     2. tolist() converts the entire column into a python list of lists
#     final Output
#     transaction=[
#     ['Milk','Bread']
#     ['Eggs']
#     ['Butter']
#     ]

# %%
transactions = df_grouped['itemDescription'].tolist()

# %%
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)
df_encoded
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 14958                  False     False             False             False
# 14959                  False     False             False             False
# 14960                  False     False             False             False
# 14961                  False     False             False             False
# 14962                  False     False             False             False
#
# ...

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)
print(frequent_itemsets)
# Out:
#      support                 itemsets
# 0   0.021386               (UHT-milk)
# 1   0.033950                   (beef)
# 2   0.021787                (berries)
# 3   0.045312           (bottled beer)
# 4   0.060683          (bottled water)
# 5   0.037626            (brown bread)
# 6   0.035220                 (butter)
# 7   0.046916            (canned beer)
# 8   0.027869                (chicken)
# 9   0.023592              (chocolate)
# 10  0.053131           (citrus fruit)
# 11  0.031611                 (coffee)
# 12  0.023658          (cream cheese )
# 13  0.033683                   (curd)
# 14  0.023592                (dessert)
# 15  0.037091          (domestic eggs)
# 16  0.037760            (frankfurter)
# 17  0.028002      (frozen vegetables)
# 18  0.034017  (fruit/vegetable juice)
# 19  0.021854         (hamburger meat)
# 20  0.032213              (margarine)
# 21  0.022121                (napkins)
# 22  0.038896             (newspapers)
# 23  0.020250                 (onions)
# ...
